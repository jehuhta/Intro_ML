# %% [markdown]
# ## Template
# _Using `Quirky Tech, Module, Transformation`_
#
# <br>
# <br>
#
#
#
#
# ### Dataset:
#
# |Parameter|Description|
# |---|---|
# |Shape|`__`|
# |Target Variable|`__`|
# |Method:|`__`
# |Extra Tools:|`__`|
# |Columns Descriptions|`__`|
#
# #### Summary:
#
# <i>
# Add Text Here.
# </i>
#
# #### Results:
#
# <i>
# Add Text Here.
# </i>
#
# <br>
# <br>

# %% [markdown]
# ---
#
# ## Code:

# %% [markdown]
# #### Imports and Data Loading

# %%
# Imports

# %% [markdown]
# ---

# %% [markdown]
# ### Data Cleaning
#
# |Step|Description|
# |---|---|
# |1|<bold style="background:yellow;color:black;"> Data Cleaning </bold>|
# |2| Transformation & Feature Engineering|
# |3| ML Training & Metrics|

# %% [markdown]
# ---
#
# ### Transformation & Feature Engineering

# %% [markdown]
# |Step|Description|
# |---|---|
# |1|Data Cleaning |
# |2|<bold style="background:yellow;color:black;">  Transformation & Feature Engineering</bold>|
# |3| ML Training & Metrics|

# %% [markdown]
# ---
#
# ### ML Training & Metrics
#
# |Step|Description|
# |---|---|
# |1|Data Cleaning |
# |2|Transformation & Feature Engineering|
# |3|<bold style="background:yellow;color:black;">   ML Training & Metrics </bold>|

# %% [markdown]
# ---
#
# ### Personal Analysis
