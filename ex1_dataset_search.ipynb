# %% [markdown]
# # Dataset Searching
# #### Exercise Project 1
#
# Purpose:
#
# The point of this notebook is to find a dataset suitable for exercise project 1.
#
# Requirements:
# |Requirements|
# |---|
# |Do not use timeseries data|
# |Have at least four numeric columns|
# |The target variable has to be continuous|
# |The data has to follow a linear trend (not seasonal, curved relationships)|
# |Has to be unique to other students|
#
# <br>
#
# ---
#
# ### Code

# %%
# Imports
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# #### Dataset Candidate 1
# [New York City Housing Prices](https://www.kaggle.com/datasets/ishank2005/nyc-housing-prices-csv)

# %%
# Reading the file onto the dataframe.
df = pd.read_csv("datasets/nyc_housing.csv")
df.head(3)
# Out:
#    borough_x  block  lot  sale_price  zip_code borough_y  yearbuilt  lotarea  \
# 0          1    400   11      280000   10009.0        MN     1900.0   2404.0
# 1          1    402   36     2000000   10009.0        MN     1900.0   1919.0
# 2          1    402   60     3400000   10009.0        MN     1920.0   2150.0
#
#    bldgarea  resarea  comarea  unitsres  unitstotal  numfloors   latitude  \
# 0    6875.0   6875.0      0.0      18.0        18.0        5.0  40.724415
# 1    7810.0   6810.0   1000.0       8.0        10.0        5.0  40.724975
# 2    6152.0   5352.0    800.0       8.0         9.0        5.0  40.725346
#
#    longitude  landuse bldgclass  building_age
# 0 -73.983891      2.0        C6         125.0
# 1 -73.981535      2.0        C4         125.0
# 2 -73.983112      4.0        C7         105.0

# %%
# 19 Columns, ~34,000 rows 
df.shape
# Out:
# (34439, 19)

# %%
# At first glance, it seems like there's quite a bit of linearity here.
sample_df = df.sample(4000)
sns.pairplot(df)

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px; box-sizing: border-box;">
#
# |Yes/No|Requirements|
# |---|---|
# |Yes|Not timeseries data|
# |Yes|Have at least four numeric columns|
# |Yes|The target variable has to be continuous|
# ||The data has to follow a linear trend (not seasonal, curved relationships)|
# |Yes|Has to be unique to other students|
#
# </div>
