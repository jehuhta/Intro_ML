# %% [markdown]
# ## Ex1 -- Advanced Exercise 3
# _Using `CatBoostRegressor`_
#
# <br>
#
# ![image.png](attachment:image.png)
#
# <br>
#
# ### Dataset: [College Placements](https://www.kaggle.com/datasets/sutariyasmit01/local-college-placements-dataset)
#
# |Parameter|Description|
# |---|---|
# |Shape|_`1050 rows, 11 columns`_|
# |Target Variable|_`CGPA`_|
# |Model:|_`CatBoostRegressor`_|
# |Extra Tools:|_`mlflow`_|
#
# <br>
# <br>
#
# </i>
#
# #### Results:
#
# <i>
# The results were actually not bad, considering the lack of correlation values. CGPA is an Indian GPA, essentially (0-10), so that means the average each prediction is off is 7%. Quite impressive, considering the strange dataset.
#
# What I want to know is whether or not the results were due to a superior model or a superior dataset!
#
# That really makes me want to dig a little deeper in how this model works. I will write a paragraph about the results of that research below.
#
# <br>
# <br>
#
# </i><b>
#
# ##### Post Research:
#
# <i></b>
#
# Catboost (Categorical Boost) uses a special type of gradient descent method (just like typical neural networks) called gradient-boosting. `CatBoostRegressor` is an ensemble model, meaning that it uses multiple ML models at once.
#
# <b> How it works:</b>
# You can give `CatBoostRegressor` a parameter of the amount of iterations it runs, which serves kind of as the 'steps' in `CatBoostRegressor` terms. But, instead of using steps -- It uses a decision-tree method, where after each iteration, it will take the residiual amount error and create another decision-tree to fix that residual amount of error. It then gets more accurate and more accurate (likely with diminishing returns).
#
# Basically, gradient-descent... Tree Edition.
#
# I'll have to see how the other models perform with this when I have time later. My theory, `LinearRegression` would perform horribly. `RandomForestRegressor` might perform ok!
#
# <br>
# <br>
#
# ##### Sources:
# |Description|Link|
# |---|---|
# |How Catboost works|[Source](https://www.geeksforgeeks.org/machine-learning/regression-using-catboost/)
# |How `CatBoostRegressor` works|[Source](https://builtin.com/machine-learning/catboost)|
#
# </i>
#
# <br>
# <br>

# %% [markdown]
# ---
#
# ## Code:

# %% [markdown]
# #### Imports and Data Loading

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import datetime as dt
import mlflow
import warnings
warnings.filterwarnings('ignore') 

# Loading the datasets
df = pd.read_csv("datasets/college_placements.csv")
df.head(5)
# Out:
#   Student_ID  Gender Branch  CGPA  Internships  Backlogs Programming_Skills  \
# 0    STU0001    Male     IT  7.66            2         0           Beginner
# 1    STU0002  Female     IT  8.44            1         2           Advanced
# 2    STU0003  Female    ECE  7.16            1         2           Beginner
# 3    STU0004    Male     ME  6.14            1         1       Intermediate
# 4    STU0005    Male     ME  6.82            2         0           Advanced
#
#    Aptitude_Score Communication_Skills  Extra_Certifications Placement_Status
# 0            97.6              Average                     0           Placed
# 1            75.5              Average                     3           Placed
# 2            76.8              Average                     1       Not Placed
# 3            55.4                 Good                     3           Placed
# 4            65.9                 Poor                     2           Placed

# %% [markdown]
# ---

# %% [markdown]
# ### Data Cleaning
#
# |Step|Description|
# |---|---|
# |1|<bold style="background:yellow;color:black;"> Data Cleaning </bold>|
# |2| Transformation & Feature Engineering|
# |3| ML Training & Metrics|

# %% [markdown]
# ##### Checking the shape (Rows, Columns)

# %%
# Let's first look at the shape
df.shape

# 1050 rows, seems fine!
# Out:
# (1050, 11)

# %% [markdown]
# #### Handling Duplicates

# %%
# Let's look at the amount of duplicates we have.
df.duplicated().value_counts()

# None, perfect.
# Out:
# False    1050
# Name: count, dtype: int64

# %% [markdown]
# #### Handling Missing Values

# %%
# Let's now check the amount of NaN values.
df.isna().sum()

# None as well! Lucky.
# Out:
# Student_ID              0
# Gender                  0
# Branch                  0
# CGPA                    0
# Internships             0
# Backlogs                0
# Programming_Skills      0
# Aptitude_Score          0
# Communication_Skills    0
# Extra_Certifications    0
# Placement_Status        0
# dtype: int64

# %% [markdown]
# #### Dropping Columns

# %%
# Dropping any columns which aren't related to the modeling.
df = df.drop(["Student_ID"], axis=1)    # This column is only for identification.

# %% [markdown]
# #### Categorical Features Isolated Case Elimination
#
# Any categorical features we create might sometimes create too many cases.
#
# That's a problem because each of these categories will be a bucket, which takes it's own weight value. I like to describe this situation like _putting a five-hundred euro bet by asking ONE person on the side of the road which team would win the Superbowl._ Naturally, that's not very statistical. So, let's look at all of these categorical variables more closely.

# %% [markdown]
# `Gender`

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      638
# Female    412
# Name: count, dtype: int64

# %% [markdown]
# `Branch`

# %%
df['Branch'].value_counts()
# Out:
# Branch
# IT     227
# CE     221
# ECE    215
# CSE    204
# ME     183
# Name: count, dtype: int64

# %% [markdown]
# `Programming_Skills`

# %%
df['Programming_Skills'].value_counts()
# Out:
# Programming_Skills
# Intermediate    495
# Beginner        346
# Advanced        209
# Name: count, dtype: int64

# %% [markdown]
# `Communication_Skills`

# %%
df["Communication_Skills"].value_counts()
# Out:
# Communication_Skills
# Average    511
# Good       329
# Poor       210
# Name: count, dtype: int64

# %% [markdown]
# `Placement_Status`

# %%
df["Placement_Status"].value_counts()
# Out:
# Placement_Status
# Placed        538
# Not Placed    512
# Name: count, dtype: int64

# %% [markdown]
# <b>Results:</b>
#
# Each of these columns seem OK! They all an adequate amount of samples to represent a statistic.

# %% [markdown]
# #### Turning Columns Into Numbers
#
# No need, I believe! Since we're using `CatBoostRegressor`

# %% [markdown]
# ---
#
# ### Transformation & Feature Engineering

# %% [markdown]
# |Step|Description|
# |---|---|
# |1|Data Cleaning |
# |2|<bold style="background:yellow;color:black;">  Transformation & Feature Engineering</bold>|
# |3| ML Training & Metrics|

# %% [markdown]
# ####  Target Variable Distribution Check
#
# The target variable here is `CGPA`, so let's analyse the distribution a bit more closely.

# %%
# Creating a scatterplot of the dependent variable.
sns.histplot(df, x="CGPA", kde=True)

# Well then. Perfect!
# Out:
# <Axes: xlabel='CGPA', ylabel='Count'>

# %%
df['Internships'].value_counts()
# import seaborn as sns
# Out:
# Internships
# 1    423
# 0    305
# 2    220
# 3    102
# Name: count, dtype: int64

# %% [markdown]
# #### Feature selection
#
# Since we have such a few amount of columns, I don't think we would need to drop columns. But just to be sure, let's look for multi-colinearity

# %%
# Creating a correlation heatmap to check for multicollinearity.
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# These correlations are ASTRONOMICALLY low. I'm suspicious that this is synthetic data with no rhyme or reason.
#
# Let's investigate and look at some more distributions.
#
# #### Investigating The Other Column Distributions

# %%
# Create a canvas as many plots as there are columns.
fig, axes = plt.subplots(1,len(df.columns), figsize=(25,3))

# For each column, create a histplot.
for index, column in enumerate(list(df.columns)):
    sns.histplot(df, x=column, ax = axes[index])

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px; box-sizing: border-box;">
#
# <h3>Observations</h3>
#
# I'm not convinced that this is actually a real dataset. These distributions are incredibly suspicious and I have a feeling we're going to get terrible results.
#
# But with that in mind, it's likely ok -- Since we're just testing `CatBoostRegressor`, we'll let it slide. No need to get a good result.
#
# </div>

# %% [markdown]
# ---
#
# ### ML Training & Metrics
#
# |Step|Description|
# |---|---|
# |1|Data Cleaning |
# |2|Transformation & Feature Engineering|
# |3|<bold style="background:yellow;color:black;">   ML Training & Metrics </bold>|

# %%
# Defining the dependent and independent variables
X = df.drop("CGPA", axis=1)
y = df["CGPA"]

cat_features = ["Gender", "Branch", "Programming_Skills", "Communication_Skills", "Placement_Status"]

# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# Initializing `CatBoostRegressor` model.
cb = CatBoostRegressor(
    iterations=1500,
    learning_rate=0.05,
    verbose = 100, 
    loss_function="RMSE",
    depth = 5      
)

# NOTES for later me:
# The parameter `verbose` refers to the progress printing. It'll show the progress print every 100 iterations
# The parameter `loss_function= "RMSE"' means it will optimize that RMSE while running the model.
# The parameter `learning_rate` refers to how many steps the gradient descent takes. The more you have, usually
# The more inaccurate it is. It takes longer though.
# The parameter `iterations` refers to how many times the tree-based model will run through another optimization run. 
# The parameter `depth` control how complex the tree becomes. 4-6 = shallow, 7-10 medium, 11+ deep. 
# It's supposedly recommended not to make it too deep or it will overfit.

# Training the model
cb.fit(X_train, y_train, cat_features=cat_features)

# Predicting the test features.
predictions = cb.predict(X_test)

# -- METRICS RECORDING -- 
mae = metrics.mean_absolute_error(y_test, predictions)
mse = metrics.mean_squared_error(y_test, predictions)
rmse = np.sqrt(metrics.mean_squared_error(y_test, predictions))
r_sq = metrics.r2_score(y_test, predictions)
# Out:
# 0:	learn: 0.9713000	total: 138ms	remaining: 3m 26s
# 100:	learn: 0.8072239	total: 5.67s	remaining: 1m 18s
# 200:	learn: 0.7329153	total: 10.7s	remaining: 1m 8s
# 300:	learn: 0.6818500	total: 14.8s	remaining: 59s
# 400:	learn: 0.6454487	total: 19s	remaining: 52.2s
# 500:	learn: 0.6125215	total: 23.4s	remaining: 46.7s
# 600:	learn: 0.5811169	total: 27.5s	remaining: 41.1s
# 700:	learn: 0.5542226	total: 31.4s	remaining: 35.8s
# 800:	learn: 0.5302780	total: 35.1s	remaining: 30.6s
# 900:	learn: 0.5080949	total: 38.9s	remaining: 25.8s
# 1000:	learn: 0.4867573	total: 43.6s	remaining: 21.7s
# 1100:	learn: 0.4659384	total: 47.6s	remaining: 17.2s
# 1200:	learn: 0.4491120	total: 51.3s	remaining: 12.8s
# 1300:	learn: 0.4337462	total: 55.9s	remaining: 8.55s
# 1400:	learn: 0.4195933	total: 59.7s	remaining: 4.22s
# 1499:	learn: 0.4039083	total: 1m 3s	remaining: 0us

# %%
# -- PRINT METRICS --
print("METRICS")
print("--------------------------")
print("MAE")
print(f"{round(mae,2)} \n")
print("MSE")
print(f"{round(mse,2)} \n")
print("RMSE")
print(f"{round(rmse,2)} \n")
print('R-squared:')
print(f"{round(r_sq,2)} \n")
# Out:
# METRICS
# --------------------------
# MAE
# 0.74
#
# MSE
# 0.89
#
# RMSE
# 0.95
#
# R-squared:
# 0.07

# %% [markdown]
# ---

# %% [markdown]
# <div style="border: 3px dashed white; padding: 10px; box-sizing: border-box;">
# <i>
#
# ### Personal Analysis (Pre-research)
#
#
# The results were actually not bad, considering the lack of correlation values. CGPA is an Indian GPA, essentially (0-10), so that means accuracy is 7%. Quite impressive, considering I hardly optimized. I noticed that the r^2 metric is quite low.
# I'm not quite sure why that is.
#
# `CatBoostRegressor` has some fancy hyperparameters, notably the `iterations` and `loss_function` parameters which let you control the effort level an depth of the model. I wonder if lots of models have this type of hyperparameter control?
#
# <b>TLDR:</b> R-squared low, MAE good. Why? I don't know.
#
# ### Post Research
#
#
# Catboost (Categorical Boost) uses a special type of gradient descent method (just like typical neural networks) called gradient-boosting. `CatBoostRegressor` is an ensemble model, meaning that it uses multiple ML models at once.
#
# <b> How it works:</b>
# You can give `CatBoostRegressor` a parameter of iterations, which serves kind of as the 'steps' for gradient descent. But, instead of using steps -- It uses a decision-tree method, where after each iteration, it will take the residiual amount error and create another decision-tree to fix that residual amount of error. These are supposedly called 'Tree-based models'
#
# Basically, gradient-descent... Tree Edition.
#
# I'll have to see how the other models perform with this when I have time later. My theory, `LinearRegression` would perform horribly. `RandomForestRegressor` might perform ok!
#
# (I ended up trying and `LinearRegression` in fact performed horribly, but the R-squared was fixed.)
#
# <b>Sources:</b>
# |Description|Link|
# |---|---|
# |How Catboost works|[Source](https://www.geeksforgeeks.org/machine-learning/regression-using-catboost/)
# |How `CatBoostRegressor` works|[Source](https://builtin.com/machine-learning/catboost)
#
# </div>

# %% [markdown]
# #### Creating a Tester Row

# %%
# As per the standard, we'll create a `tester_row` 
tester_row = {
    "Gender": "Male",
    "Branch": "IT",
    "Internships": 2,
    "Backlogs": 0,
    "Programming_Skills": "Beginner",
    "Aptitude_Score": 94,
    "Communication_Skills": "Average",
    "Extra_Certifications": 2,
    "Placement_Status": "Placed"
}

# Turn the dict into a dataframe, predict, and print the result.
tester_row = pd.DataFrame([tester_row])
result = cb.predict(tester_row)[0]
print(f"The CGPA of this student is predicted as: \n {result.round(2)}")
# Out:
# The CGPA of this student is predicted as:
#  7.59
